# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/new-tata-dataset/NSE-TATAGLOBAL.csv

# %% [markdown]
# # NSE-TATAGLOBAL DATASETS

# %% [markdown]
# # Stock Market Prediction And Forecasting Using Stacked LSTM

# %% [markdown]
# ### To build the stock price prediction model, we will use the NSE TATA GLOBAL dataset. This is a dataset of Tata Beverages from Tata Global Beverages Limited, National Stock Exchange of India: Tata Global Dataset

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import io
import requests 
import datetime

# %% [markdown]
# ## Import Datasets

# %%
df = pd.read_csv('../input/new-tata-dataset/NSE-TATAGLOBAL.csv')
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
df1 = pd.read_csv('../input/new-tata-dataset/NSE-TATAGLOBAL.csv')
df1.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %% [markdown]
# ## Shape of data

# %%
df.shape
# Out:
# (2035, 8)

# %% [markdown]
# ## Gathering information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
df.dtypes
# Out:
# Date                     object
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity      int64
# Turnover (Lacs)         float64
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Total percentage of data is missing

# %%
missing_values_count = df.isnull().sum()

total_cells = np.product(df.shape)

total_missing = missing_values_count.sum()

percentage_missing = (total_missing/total_cells)*100

print(percentage_missing)
# Out:
# 0.0

# %%
NAN = [(c, df[c].isnull().mean()*100) for c in df]
NAN = pd.DataFrame(NAN, columns=['column_name', 'percentage'])
NAN
# Out:
#             column_name  percentage
# 0                  Date         0.0
# 1                  Open         0.0
# 2                  High         0.0
# 3                   Low         0.0
# 4                  Last         0.0
# 5                 Close         0.0
# 6  Total Trade Quantity         0.0
# 7       Turnover (Lacs)         0.0

# %% [markdown]
# # Data Visualisation

# %%
sns.set(rc = {'figure.figsize': (20, 5)})
df['Open'].plot(linewidth = 1,color='blue')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
cols_plot = ['Open','High','Low','Last','Close']
axes = df[cols_plot].plot(alpha = 1, figsize=(20, 30), subplots = True)

for ax in axes:
    ax.set_ylabel('Variation')

# %% [markdown]
# ## Sort the dataset on date time and filter “Date” and “Open” columns

# %%
df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.index=df['Date']
df
# Out:
#                  Date    Open    High     Low    Last   Close  \
# Date
# 2018-09-28 2018-09-28  234.05  235.95  230.20  233.50  233.75
# 2018-09-27 2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2018-09-26 2018-09-26  240.00  240.00  232.50  235.00  234.25
# 2018-09-25 2018-09-25  233.30  236.75  232.00  236.25  236.10
# 2018-09-24 2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...               ...     ...     ...     ...     ...     ...
# 2010-07-27 2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2010-07-26 2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2010-07-23 2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2010-07-22 2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2010-07-21 2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2018-09-28               3069914          7162.35
# 2018-09-27               5082859         11859.95
# 2018-09-26               2240909          5248.60
# 2018-09-25               2349368          5503.90
# 2018-09-24               3423509          7999.55
# ...                          ...              ...
# 2010-07-27                586100           694.98
# 2010-07-26                658440           780.01
# 2010-07-23                281312           340.31
# 2010-07-22                293312           355.17
# 2010-07-21                658666           803.56
#
# [2035 rows x 8 columns]

# %%
del df["Date"]

# %%
df.dtypes
# Out:
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity      int64
# Turnover (Lacs)         float64
# dtype: object

# %% [markdown]
# ## 7 day rolling mean

# %%
df.rolling(7).mean().head(10)
# Out:
#                   Open        High         Low        Last       Close  \
# Date
# 2018-09-28         NaN         NaN         NaN         NaN         NaN
# 2018-09-27         NaN         NaN         NaN         NaN         NaN
# 2018-09-26         NaN         NaN         NaN         NaN         NaN
# 2018-09-25         NaN         NaN         NaN         NaN         NaN
# 2018-09-24         NaN         NaN         NaN         NaN         NaN
# 2018-09-21         NaN         NaN         NaN         NaN         NaN
# 2018-09-19  235.200000  237.557143  231.135714  234.414286  234.307143
# 2018-09-18  235.750000  238.028571  231.607143  234.700000  234.492857
# 2018-09-17  235.550000  238.200000  231.485714  235.071429  234.971429
# 2018-09-14  233.185714  237.728571  230.171429  234.928571  234.928571
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2018-09-28                   NaN              NaN
# 2018-09-27                   NaN              NaN
# 2018-09-26                   NaN              NaN
# 2018-09-25                   NaN              NaN
# 2018-09-24                   NaN              NaN
# 2018-09-21                   NaN              NaN
# 2018-09-19          3.274848e+06      7652.388571
# 2018-09-18          3.209831e+06      7509.724286
# 2018-09-17          2.936693e+06      6879.075714
# 2018-09-14          3.527693e+06      8241.347143

# %%
df['Open'].plot(figsize=(20,8),alpha = 1)
df.rolling(window=30).mean()['Close'].plot(alpha = 1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close: 30 Day Mean'] = df['Close'].rolling(window=30).mean()
df[['Close','Close: 30 Day Mean']].plot(figsize=(20,8),alpha = 1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Optional specify a minimum number of periods

# %%
df['Close'].expanding(min_periods=1).mean().plot(figsize=(20,8),alpha = 1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df2=df1.reset_index()['Open']
df2
# Out:
# 0       234.05
# 1       234.55
# 2       240.00
# 3       233.30
# 4       233.55
#          ...
# 2030    117.60
# 2031    120.10
# 2032    121.80
# 2033    120.30
# 2034    122.10
# Name: Open, Length: 2035, dtype: float64

# %%
plt.plot(df2)

# %% [markdown]
# ## LSTM are sensitive to the scale of the data. so we apply MinMax scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df2=scaler.fit_transform(np.array(df2).reshape(-1,1))
print(df2)
# Out:
# [[0.6202352 ]
#  [0.62226277]
#  [0.64436334]
#  ...
#  [0.16504461]
#  [0.15896188]
#  [0.16626115]]

# %% [markdown]
# ## splitting dataset into train and test split

# %%
train_size=int(len(df2)*0.75)
test_size=len(df2)-train_size
train_data,test_data=df2[0:train_size,:],df2[train_size:len(df2),:1]

# %%
train_size,test_size
# Out:
# (1526, 509)

# %%
train_data,test_data
# Out:
# (array([[0.6202352 ],
#         [0.62226277],
#         [0.64436334],
#         ...,
#         [0.18491484],
#         [0.15774534],
#         [0.16180049]]),
#  array([[0.15774534],
#         [0.15774534],
#         [0.16991079],
#         [0.13746959],
#         [0.14963504],
#         [0.16605839],
#         [0.15369019],
#         [0.14152474],
#         [0.13341444],
#         [0.13260341],
#         [0.12368208],
#         [0.12246553],
#         [0.13625304],
#         [0.11719384],
#         [0.13746959],
#         [0.15004055],
#         [0.15308191],
#         [0.15794809],
#         [0.15186537],
#         [0.14557989],
#         [0.14497161],
#         [0.14801298],
#         [0.14476886],
#         [0.11719384],
#         [0.11151663],
#         [0.10563666],
#         [0.10218978],
#         [0.09712084],
#         [0.09691809],
#         [0.11131387],
#         [0.10644769],
#         [0.16707218],
#         [0.17112733],
#         [0.17639903],
#         [0.18349554],
#         [0.1717356 ],
#         [0.16423358],
#         [0.16991079],
#         [0.17619627],
#         [0.16788321],
#         [0.16909976],
#         [0.17396594],
#         [0.17741281],
#         [0.18268451],
#         [0.19221411],
#         [0.18896999],
#         [0.19018654],
#         [0.17396594],
#         [0.17092457],
#         [0.16788321],
#         [0.17477697],
#         [0.16443633],
#         [0.14557989],
#         [0.15287916],
#         [0.15369019],
#         [0.15044607],
#         [0.14152474],
#         [0.15145985],
#         [0.13341444],
#         [0.12530414],
#         [0.11719384],
#         [0.11780211],
#         [0.12489862],
#         [0.14132198],
#         [0.13098135],
#         [0.12935929],
#         [0.13240065],
#         [0.12895377],
#         [0.12530414],
#         [0.13381995],
#         [0.14557989],
#         [0.15166261],
#         [0.15085158],
#         [0.14679643],
#         [0.14355231],
#         [0.12733171],
#         [0.14963504],
#         [0.14801298],
#         [0.15815085],
#         [0.16504461],
#         [0.15896188],
#         [0.16626115]]))

# %% [markdown]
# ## convert an array of values into a dataset matrix

# %%
def create_dataset(dataset, time_step=1):
    train_X, train_Y = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        train_X.append(a)
        train_Y.append(dataset[i + time_step, 0])
    return numpy.array(train_X), numpy.array(train_Y)

# %% [markdown]
# ## reshape into X=t,t+1,t+2,t+3 and Y=t+4

# %%
import numpy
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1425, 100)
# (1425,)
# (None, None)

# %% [markdown]
# ## reshape input to be [samples, time steps, features] which is required for LSTM

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %% [markdown]
# ## Create the Stacked LSTM model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

# %%
model=Sequential()
model.add(LSTM(units = 75, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.1))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.1))

model.add(LSTM(units = 75))
model.add(Dropout(0.2))

model.add(Dense(units = 1))

model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 75)           23100
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 75)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           25200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 50)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100, 50)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 75)                37800
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 75)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 76
# =================================================================
# Total params: 106,376
# Trainable params: 106,376
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=20,batch_size=64)
# Out:
# Epoch 1/20
# 23/23 [==============================] - 13s 94ms/step - loss: 0.0529 - val_loss: 0.0019
# Epoch 2/20
# 23/23 [==============================] - 1s 24ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 3/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 4/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 5/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 6/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 7/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 8/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 9/20
# 23/23 [==============================] - 1s 29ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 10/20
# 23/23 [==============================] - 1s 26ms/step - loss: 0.0028 - val_loss: 7.1101e-04
# Epoch 11/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 12/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 13/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 14/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 15/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 16/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 17/20
# 23/23 [==============================] - 1s 24ms/step - loss: 0.0029 - val_loss: 8.7262e-04
# Epoch 18/20
# 23/23 [==============================] - 1s 24ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 19/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0018 - val_loss: 5.5281e-04
# Epoch 20/20
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0019 - val_loss: 6.5478e-04

# %%
import tensorflow as tf

# %% [markdown]
# ## Lets Do the prediction and check performance metrics

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# ## Calculate RMSE performance metrics

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 163.04995276287806

# %% [markdown]
# ## Test Data RMSE

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 107.45489563325938

# %% [markdown]
# ## shift train predictions for plotting

# %%
look_back=100
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

# %% [markdown]
# ## shift test predictions for plotting

# %%
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict

# %% [markdown]
# ## plot baseline and predictions

# %%
pred  = scaler.inverse_transform(df2)
plt.plot(pred,color='blue')
plt.show()

# %%
plt.plot(trainPredictPlot,color='red')
plt.show()
plt.plot(testPredictPlot,color='green')
plt.show()

# %%
plt.plot(trainPredictPlot,color='red')
plt.plot(testPredictPlot,color='green')
plt.show()

# %%
plt.plot(pred,color='blue')
plt.plot(trainPredictPlot,color='red')
plt.plot(testPredictPlot,color='green')
plt.show()

# %%
len(test_data)
# Out:
# 509

# %%
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 168)

# %% [markdown]
# ## Save the Model

# %%
model.save("saved_model.h5")
